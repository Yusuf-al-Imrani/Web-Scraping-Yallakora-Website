# %%
import requests
from bs4 import BeautifulSoup 
import lxml
import csv
from datetime import datetime

import numpy as np

# %% [markdown]
# #### Taking day date from user

# %%
# Accept input from user
date_string = input("Enter a date in the format mm/dd/yyyy: ")
print("You entered: ", date_string)

from datetime import datetime

# Convert date string to datetime object
date_object = datetime.strptime(date_string, '%m/%d/%Y').date()
print("After changing it to data: ", date_object)

# Convert datetime object back to string with new format
new_date_string = datetime.strftime(date_object, '%m-%d-%Y')
print("After converted back to string on the format %m-%d-%Y: ", new_date_string)
# Out:
# Enter a date in the format mm/dd/yyyy: 3/4/2023
# You entered:  3/4/2023
# After changing it to data:  2023-03-04
# After converted back to string on the format %m-%d-%Y:  03-04-2023

# %%
# Storing file name and file path in global variables to be used in multiple cells
file_name = f"Match_Data_Scraped_{new_date_string}.csv"
file_path = "C:/Users/yusuf/Data Science/Projects/Web Scraping/Yallakor.com"
path = file_path+"/"+file_name

# %%
# Requesting the webpage and adding the date to it
page = requests.get(f"https://www.yallakora.com/match-center?date={date_string}")
website_URL = "https://www.yallakora.com"

# Checking the response of the getting the page, if respose is 200; this means we got it fine
page
# Out:
# <Response [200]>

# %% [markdown]
# ###  Function that extract match details from championship segment of the webpage

# %%
 """
 championship; championship block that conatains multiple matches 
 championship_title; the championship title
 match_details; 
 """
def scrape_single_match_details(championship, championship_title): #, match_details):
    
    match_details = []

    # Loopting through all matches to collect match details in current championship
    for match in championship:

        # Start scraping each match details
        team_a = match.find("div",{"class":"allData"}
                                          ).find_next("div", {"class":"teamsData"}
                                                     ).find_next("div", {"class":"teams teamA"}
                                                        ).find_next("p").text

        team_b = match.find("div",{"class":"allData"}
                                  ).find_next("div", {"class":"teamsData"}
                                             ).find_next("div", {"class":"teams teamB"}
                                                        ).find_next("p").text

        time = match.find("div",{"class":"allData"}
                                  ).find_next("div", {"class":"teamsData"}
                                             ).find_next("div", {"class":"MResult"}
                                                        ).find_next("span"
                                                                   ).find_next("span"
                                                                              ).find_next("span"
                                                                                         ).find_next("span").text
        team_a_score = match.find("div",{"class":"allData"}
                                  ).find_next("div", {"class":"teamsData"}
                                             ).find_next("div", {"class":"MResult"}
                                                        ).find_next("span").text

        team_b_score = match.find("div",{"class":"allData"}
                                  ).find_next("div", {"class":"teamsData"}
                                             ).find_next("div", {"class":"MResult"}
                                                        ).find_next("span"
                                                                   ).find_next("span"
                                                                              ).find_next("span").text

        match_status = match.find("div",{"class":"matchStatus"}).find_next('span').text

        # Used getattr func to allocate None if there is no value in the webpage
        chanel_streaming = getattr(match.find("div",{"class":"channel icon-channel"}), 'text', None)

        match_detail_link = website_URL + match.find("div",{"class":"leftCol"}
                                                           ).find_next('a')['href']

        match_week_number = match.find("div",{"class":"date"}).text.strip()
        
        # Storing the values in dictionary
        match = {'Date':date_object, 'Championship_Title':championship_title, 'Team_A':team_a, 'Team_B':team_b,
                 'Time':time, 'Team_A_Score':team_a_score, 'Team_B_Score':team_b_score,
                 'Match_Status':match_status, 'Chanel_Streaming':chanel_streaming,
                 'Match_Detail_Link':match_detail_link,'Match_Week_Number':match_week_number}

        # Appending the match data to match_details list
        match_details.append(match)

    return(match_details)

# %% [markdown]
# #### Function that collects championship details

# %%
def get_championship_details(championships, match_details):
    
    # List to store every match details
    big_match_details = []
    
    i = 0
    # Looping through championships
    for championship in championships:

        championship_title = championship.find("a",{"class":"tourTitle"}).find_next("h2").text.strip()

        # Storing the each championship matches in list
        championship_matches = championship.find_all("li", {"class":"item finish"})

        # Getting data for every match in the champtionship
        match_details_after_scraping = scrape_single_match_details(championship_matches,
                                                                   championship_title) #, match_details)
        

        # Adding each championship matches details to the main list
        i +=1 
        if i <= 1:  # To distinguish first cycle
            big_match_details = match_details_after_scraping # First cycle for the loop
        else: 
            big_match_details = big_match_details + match_details_after_scraping # Later cycles
            
    return (big_match_details)

# %% [markdown]
#  #### Funtion that stores championships' matches data in csv file

# %%
# Function to store the data scraped in csv file

def store_in_csv(match_details, file_name, path):

    # Creating Keys to use in match dictionary
    keys = ['Date', 'Championship_Title', 'Team_A', 'Team_B', 'Time', 'Team_A_Score', 'Team_B_Score',
            'Match_Status', 'Chanel_Streaming', 'Match_Detail_Link','Match_Week_Number']

    # Storing the championships details in csv file
    with open(path, 'w', newline="") as match_data:
        dict_writer = csv.DictWriter(match_data, fieldnames=keys) 
        dict_writer.writeheader()

        # Looping through championships to store its data
        for match in match_details: 
            dict_writer.writerow(match)

        # Checking the file creation is done
        print(f"Match data saved to file {file_name}")

# %% [markdown]
# ####  The main function that scrape the website contect

# %%
# Function to do the steps of scraping
def scraping(page):
    
    match_details = []
    
    src = page.content
    soup =  BeautifulSoup(src, "lxml")

    # Each championship in the entered data
    championships = soup.find_all("div", {'class':'matchCard'})    
    
    # Gets championships all matches details    
    all_matches_details = get_championship_details(championships, match_details)
    
    #match_details.append(get_championships_details(championships, match_details))
    
    # Calling the function that stores the data scraped in csv file
    store_in_csv(all_matches_details, file_name, path)
    
    #return(match_details)

# %% [markdown]
# #### Calling the main function

# %%
scraping(page)
# Out:
# Match data saved to file Match_Data_Scraped_03-04-2023.csv

# %% [markdown]
# ## Working on the resulted data
#
# ### Openning the csv file and show the data

# %%
#Importing Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from six.moves import urllib
import os

# %%
#function to read the data

def load_data(file_path, file_name):
    
    csv_path = os.path.join(file_path, file_name)
    
    return(pd.read_csv(csv_path))

# %%
# Loading the data using the load_data function
data = load_data(file_path, file_name)

# %%
data
# Out:
#           Date  Championship_Title           Team_A            Team_B   Time  \
# 0   2023-03-04  دوري أبطال إفريقيا           الأهلي  القطن الكاميروني  18:00
# 1   2023-03-04    الدوري الإنجليزي     مانشستر سيتي           نيوكاسل  14:30
# 2   2023-03-04    الدوري الإنجليزي      تشيلسي           ليدز يونايتد  17:00
# 3   2023-03-04    الدوري الإنجليزي     استون فيلا      كريستال بالاس   17:00
# 4   2023-03-04    الدوري الإنجليزي     وولفرهامبتون    توتنهام هوتسبر  17:00
# 5   2023-03-04    الدوري الإنجليزي          برايتون   وست هام يونايتد  17:00
# 6   2023-03-04    الدوري الإنجليزي           أرسنال           بورنموث  17:00
# 7   2023-03-04    الدوري الإنجليزي       ساوثامبتون        ليستر سيتي  19:30
# 8   2023-03-04     الدوري الإسباني           خيتافي            جيرونا  15:00
# 9   2023-03-04     الدوري الإسباني          الميريا           فياريال  17:15
# 10  2023-03-04     الدوري الإسباني         مايوركا              إلتشي  19:30
# 11  2023-03-04     الدوري الإسباني    اتلتيكو مدريد          اشبيلية   22:00
# 12  2023-03-04     الدوري الإيطالي            مونزا            إمبولي  16:00
# 13  2023-03-04     الدوري الإيطالي         أتالانتا          أودينيزي  19:00
# 14  2023-03-04     الدوري الإيطالي        فيورنتينا             ميلان  21:45
# 15  2023-03-04     الدوري الألماني            ماينز          هوفنهايم  16:30
# 16  2023-03-04     الدوري الألماني     مونشنجلادباخ          فرايبورج  16:30
# 17  2023-03-04     الدوري الألماني     يونيون برلين              كولن  16:30
# 18  2023-03-04     الدوري الألماني            بوخوم             شالكه  16:30
# 19  2023-03-04     الدوري الألماني         أوجسبورج       فيردر بريمن  16:30
# 20  2023-03-04     الدوري الألماني         شتوتجارت      بايرن ميونيخ  19:30
# 21  2023-03-04      الدوري الفرنسي             لانس               ليل  18:00
# 22  2023-03-04      الدوري الفرنسي     ب. س. جيرمان              نانت  22:00
# 23  2023-03-04       الدوري التركي  فاتح كاراجومروك          سيفاسبور  12:30
# 24  2023-03-04       الدوري التركي     طرابزون سبور      أومراني سبور  15:00
# 25  2023-03-04       الدوري التركي       قيصري سبور           فنربخشة  18:00
# 26  2023-03-04      الدوري السعودي              ضمك           التعاون  15:00
# 27  2023-03-04      الدوري السعودي           الشباب           العدالة  19:30
# 28  2023-03-04    الدوري البرتغالي        إستوريل\t           فيزيلا   17:30
# 29  2023-03-04    الدوري البرتغالي     بورتيمونينسي   سبورتينج لشبونة  20:00
# 30  2023-03-04    الدوري البرتغالي            شافيش             بورتو  22:30
# 31  2023-03-04      الدوري المغربي   الدفاع الجديدي      الجيش الملكي  17:00
# 32  2023-03-04      الدوري المغربي       اتحاد طنجة      أولمبيك آسفي  17:00
# 33  2023-03-04      الدوري المغربي  الرجاء البيضاوي     شباب المحمدية  19:15
# 34  2023-03-04      الدوري المغربي     مولودية وجدة      حسنية اغادير  21:30
#
#     Team_A_Score  Team_B_Score Match_Status       Chanel_Streaming  \
# 0              3             0        انتهت       بى ان سبورت 4 HD
# 1              2             0        انتهت  بى ان سبورت بريميوم 1
# 2              1             0        انتهت  بى ان سبورت بريميوم 2
# 3              1             0        انتهت   بى ان سبورت اكسترا 1
# 4              1             0        انتهت  بى ان سبورت بريميوم 3
# 5              4             0        انتهت   بى ان سبورت اكسترا 2
# 6              3             2        انتهت  بى ان سبورت بريميوم 1
# 7              1             0        انتهت                    NaN
# 8              3             2        انتهت        بى ان سبورت 1HD
# 9              0             2        انتهت        بى ان سبورت 1HD
# 10             0             1        انتهت        بى ان سبورت 1HD
# 11             6             1        انتهت        بى ان سبورت 1HD
# 12             2             1        انتهت         Starz Play App
# 13             0             0        انتهت         Starz Play App
# 14             2             1        انتهت         Starz Play App
# 15             1             0        انتهت                    NaN
# 16             0             0        انتهت       بى ان سبورت 6 HD
# 17             0             0        انتهت       بى ان سبورت 3 HD
# 18             0             2        انتهت                    NaN
# 19             2             1        انتهت       بى ان سبورت 7 HD
# 20             1             2        انتهت  بى ان سبورت بريميوم 1
# 21             1             1        انتهت       بى ان سبورت 2 HD
# 22             4             2        انتهت  بى ان سبورت بريميوم 1
# 23             4             3        انتهت                    NaN
# 24             1             2        انتهت                    NaN
# 25             1             2        انتهت                    NaN
# 26             1             2        انتهت                    NaN
# 27             1             2        انتهت                    NaN
# 28             0             3        انتهت                    NaN
# 29             0             1        انتهت                    NaN
# 30             1             3        انتهت                    NaN
# 31             0             1        انتهت                    NaN
# 32             2             1        انتهت                    NaN
# 33             1             0        انتهت                    NaN
# 34             2             0        انتهت                    NaN
#
#                                     Match_Detail_Link        Match_Week_Number
# 0   https://www.yallakora.com/african-champions-le...            الجولة الاولي
# 1   https://www.yallakora.com/epl/2761/match/87025...  الأسبوع السادس والعشرون
# 2   https://www.yallakora.com/epl/2761/match/87026...  الأسبوع السادس والعشرون
# 3   https://www.yallakora.com/epl/2761/match/87027...  الأسبوع السادس والعشرون
# 4   https://www.yallakora.com/epl/2761/match/87028...  الأسبوع السادس والعشرون
# 5   https://www.yallakora.com/epl/2761/match/87029...  الأسبوع السادس والعشرون
# 6   https://www.yallakora.com/epl/2761/match/87030...  الأسبوع السادس والعشرون
# 7   https://www.yallakora.com/epl/2761/match/87031...  الأسبوع السادس والعشرون
# 8   https://www.yallakora.com/la-liga/2764/match/8...  الأسبوع الرابع والعشرون
# 9   https://www.yallakora.com/la-liga/2764/match/8...  الأسبوع الرابع والعشرون
# 10  https://www.yallakora.com/la-liga/2764/match/8...  الأسبوع الرابع والعشرون
# 11  https://www.yallakora.com/la-liga/2764/match/8...  الأسبوع الرابع والعشرون
# 12  https://www.yallakora.com/serie-a/2765/match/8...  الأسبوع الخامس والعشرون
# 13  https://www.yallakora.com/serie-a/2765/match/8...  الأسبوع الخامس والعشرون
# 14  https://www.yallakora.com/serie-a/2765/match/8...  الأسبوع الخامس والعشرون
# 15  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 16  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 17  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 18  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 19  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 20  https://www.yallakora.com/bundesliga/2769/matc...  الأسبوع الثالث والعشرون
# 21  https://www.yallakora.com/ligue1/2768/match/87...  الأسبوع السادس والعشرون
# 22  https://www.yallakora.com/ligue1/2768/match/87...  الأسبوع السادس والعشرون
# 23  https://www.yallakora.com/turkish-super-lig/27...  الأسبوع الرابع والعشرون
# 24  https://www.yallakora.com/turkish-super-lig/27...  الأسبوع الرابع والعشرون
# 25  https://www.yallakora.com/turkish-super-lig/27...  الأسبوع الرابع والعشرون
# 26  https://www.yallakora.com/ksa-league/2784/matc...       الأسبوع التاسع عشر
# 27  https://www.yallakora.com/ksa-league/2784/matc...       الأسبوع التاسع عشر
# 28  https://www.yallakora.com/primeira-liga/2775/m...  الأسبوع الثالث والعشرون
# 29  https://www.yallakora.com/primeira-liga/2775/m...  الأسبوع الثالث والعشرون
# 30  https://www.yallakora.com/primeira-liga/2775/m...  الأسبوع الثالث والعشرون
# 31  https://www.yallakora.com/morrocan-league/2794...       الأسبوع التاسع عشر
# 32  https://www.yallakora.com/morrocan-league/2794...       الأسبوع التاسع عشر
# 33  https://www.yallakora.com/morrocan-league/2794...       الأسبوع التاسع عشر
# 34  https://www.yallakora.com/morrocan-league/2794...       الأسبوع التاسع عشر
